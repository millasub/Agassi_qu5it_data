# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": "Computer Modern",
    "font.size": 12
})
plt.rcParams['figure.dpi']= 200

# %%
fig = plt.figure(figsize=(5.5, 1.6))
axs = fig.subplots(1,2, sharex=True)
plt.subplots_adjust(left=0.1, bottom=0.26, right=0.985, top=0.95, wspace=0.2, hspace=0.04)

colortrot =['#674A40','#50A3A4','#FCAF38','#F95335']

datapsi0N1 = np.empty((4,2,401))
dataTzN1 = np.empty((4,2,401))

datapsi0N1[0,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np1_set1.dat'))
datapsi0N1[1,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np1_set2.dat'))
datapsi0N1[2,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np1_set3.dat'))
datapsi0N1[3,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np1_set4.dat'))

dataTzN1[0,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np1_set1.dat'))
dataTzN1[1,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np1_set2.dat'))
dataTzN1[2,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np1_set3.dat'))
dataTzN1[3,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np1_set4.dat'))

axs[0].plot(datapsi0N1[0,0],datapsi0N1[0,1],c=colortrot[0],marker='',ls='-',label=r'$\rm{{set}}$-$1$')
axs[0].plot(datapsi0N1[1,0],datapsi0N1[1,1],c=colortrot[2],marker='',ls='-',label=r'$\rm{{set}}$-$2,3$')
axs[0].plot(datapsi0N1[3,0],datapsi0N1[3,1],c=colortrot[3],marker='',ls='-',label=r'$\rm{{set}}$-$4$')
axs[0].legend(ncol=1,handlelength=1,columnspacing=1, fontsize=10,loc='lower right')
axs[0].set_xlim([-0.05,2.05])
axs[0].set_ylabel(r'$|\langle \psi(t)|\psi(0)\rangle|^2$', fontsize=12)
axs[0].tick_params(right=True, top=True, direction='in')
axs[0].text(0.08, 0.12, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=axs[0].transAxes)
axs[0].set_xlabel(r'$t$', fontsize=12)

for inds in range(4):
    axs[1].plot(dataTzN1[inds,0],dataTzN1[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1].set_xlabel(r'$t$', fontsize=12)
axs[1].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-5)
axs[1].set_xticks([0,0.5,1,1.5,2])
axs[1].tick_params(right=True, top=True, direction='in')
axs[1].text(0.08, 0.89, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=axs[1].transAxes)


with PdfPages('Nq1_initwvfn2.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()

# %%
fig = plt.figure(figsize=(5.5, 4))
axs = fig.subplots(3,2, sharex=True)
plt.subplots_adjust(left=0.10, bottom=0.1, right=0.98, top=0.93, wspace=0.2, hspace=0.04)

colortrot =['#674A40','#50A3A4','#FCAF38','#F95335']

dataPsi0N4 = np.empty((4,2,401))
dataNpairN4 = np.empty((4,2,401))
dataTzN4 = np.empty((4,2,401))

dataPsi0N4v2 = np.empty((4,2,401))
dataNpairN4v2 = np.empty((4,2,401))
dataTzN4v2 = np.empty((4,2,401))

dataPsi0N4[0,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set1.dat'))
dataPsi0N4[1,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set2.dat'))
dataPsi0N4[2,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set3.dat'))
dataPsi0N4[3,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set4.dat'))

dataNpairN4[0,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set1.dat'))
dataNpairN4[1,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set2.dat'))
dataNpairN4[2,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set3.dat'))
dataNpairN4[3,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set4.dat'))

dataTzN4[0,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set1.dat'))
dataTzN4[1,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set2.dat'))
dataTzN4[2,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set3.dat'))
dataTzN4[3,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set4.dat'))

dataPsi0N4v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set1.dat'))
dataPsi0N4v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set2.dat'))
dataPsi0N4v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set3.dat'))
dataPsi0N4v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set4.dat'))

dataNpairN4v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set1.dat'))
dataNpairN4v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set2.dat'))
dataNpairN4v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set3.dat'))
dataNpairN4v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set4.dat'))

dataTzN4v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set1.dat'))
dataTzN4v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set2.dat'))
dataTzN4v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set3.dat'))
dataTzN4v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set4.dat'))

for inds in range(4):
    axs[0,0].plot(dataPsi0N4v2[inds,0],dataPsi0N4v2[inds,1],c=colortrot[inds],marker='',ls='-',label=rf'$\rm{{set}}$-${inds+1}$')
axs[0,0].legend(ncol=2,handlelength=1,columnspacing=1, fontsize=10,loc='upper right')
axs[0,0].set_xlim([-0.05,2.05])
axs[0,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[0,0].tick_params(right=True, top=True, direction='in')
axs[0,0].title.set_text(r'$| \psi (0) \rangle_A=|1\rangle^{{\otimes 4}}$')
axs[0,0].text(0.08, 0.12, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=axs[0,0].transAxes)

for inds in range(4):
    axs[0,1].plot(dataPsi0N4[inds,0],dataPsi0N4[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,1].tick_params(right=True, top=True, direction='in')
axs[0,1].title.set_text(r'$| \psi (0) \rangle_B=|4\rangle^{{\otimes 2}}|0\rangle^{{\otimes 2}}$')
axs[0,1].text(0.93, 0.88, r'\bf (d)', horizontalalignment='center', verticalalignment='center', transform=axs[0,1].transAxes)

for inds in range(4):
    axs[1,0].plot(dataNpairN4v2[inds,0],dataNpairN4v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,0].set_ylim([2.7,4.1])
axs[1,0].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[1,0].tick_params(right=True, top=True, direction='in')
axs[1,0].text(0.93, 0.88, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=axs[1,0].transAxes)

for inds in range(4):
    axs[1,1].plot(dataNpairN4[inds,0],dataNpairN4[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,1].set_ylim([2.7,4.1])
axs[1,1].tick_params(right=True, top=True, direction='in')
axs[1,1].text(0.93, 0.88, r'\bf (e)', horizontalalignment='center', verticalalignment='center', transform=axs[1,1].transAxes)

for inds in range(4):
    axs[2,0].plot(dataTzN4v2[inds,0],dataTzN4v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[2,0].set_xlabel(r'$t$', fontsize=12)
axs[2,0].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12)
axs[2,0].set_xticks([0,0.5,1,1.5,2])
axs[2,0].set_ylim([-4.2,4.2])
axs[2,0].set_yticks([-4,-2,0,2,4])
axs[2,0].tick_params(right=True, top=True, direction='in')
axs[2,0].text(0.93, 0.88, r'\bf (c)', horizontalalignment='center', verticalalignment='center', transform=axs[2,0].transAxes)

for inds in range(4):
    axs[2,1].plot(dataTzN4[inds,0],dataTzN4[inds,1],c=colortrot[inds],marker='',ls='-')
axs[2,1].set_xlabel(r'$t$', fontsize=12)
axs[2,1].set_ylim([-4.2,4.2])
axs[2,1].set_yticks([-4,-2,0,2,4])
axs[2,1].tick_params(right=True, top=True, direction='in')
axs[2,1].text(0.93, 0.88, r'\bf (f)', horizontalalignment='center', verticalalignment='center', transform=axs[2,1].transAxes)

fig.align_ylabels()

with PdfPages('Nq4_initwvfn12.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()

# %%
fig = plt.figure(figsize=(9, 3.5))
axs = fig.subplots(2,3, sharex=True)
plt.subplots_adjust(left=0.08, bottom=0.1, right=0.99, top=0.93, wspace=0.2, hspace=0.2)

colortrot =['#674A40','#50A3A4','#FCAF38','#F95335']

dataPsi0N4 = np.empty((4,2,1501))
dataNpairN4 = np.empty((4,2,1501))
dataTzN4 = np.empty((4,2,1501))

dataPsi0N4v2 = np.empty((4,2,1501))
dataNpairN4v2 = np.empty((4,2,1501))
dataTzN4v2 = np.empty((4,2,1501))

dataPsi0N4[0,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set1_longT.dat'))
dataPsi0N4[1,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set2_longT.dat'))
dataPsi0N4[2,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set3_longT.dat'))
dataPsi0N4[3,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np4_set4_longT.dat'))

dataNpairN4[0,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set1_longT.dat'))
dataNpairN4[1,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set2_longT.dat'))
dataNpairN4[2,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set3_longT.dat'))
dataNpairN4[3,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np4_set4_longT.dat'))

dataTzN4[0,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set1_longT.dat'))
dataTzN4[1,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set2_longT.dat'))
dataTzN4[2,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set3_longT.dat'))
dataTzN4[3,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np4_set4_longT.dat'))

dataPsi0N4v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set1_longT.dat'))
dataPsi0N4v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set2_longT.dat'))
dataPsi0N4v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set3_longT.dat'))
dataPsi0N4v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np4_set4_longT.dat'))

dataNpairN4v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set1_longT.dat'))
dataNpairN4v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set2_longT.dat'))
dataNpairN4v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set3_longT.dat'))
dataNpairN4v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np4_set4_longT.dat'))

dataTzN4v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set1_longT.dat'))
dataTzN4v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set2_longT.dat'))
dataTzN4v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set3_longT.dat'))
dataTzN4v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np4_set4_longT.dat'))

for inds in range(4):
    axs[0,0].plot(dataPsi0N4v2[inds,0],dataPsi0N4v2[inds,1],c=colortrot[inds],marker='',ls='-',label=rf'$\rm{{set}}$-${inds+1}$')
axs[0,0].legend(ncol=2,handlelength=1,columnspacing=1, fontsize=10,loc='upper right')
axs[0,0].set_xlim([-0.05,8.05])
axs[0,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[0,0].tick_params(right=True, top=True, direction='in')
axs[0,0].set_title(r'$| \psi (0) \rangle_A=|1\rangle^{{\otimes 4}}$',loc='left', fontsize=12)
axs[0,0].text(0.08, 0.88, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=axs[0,0].transAxes)

for inds in range(4):
    axs[1,0].plot(dataPsi0N4[inds,0],dataPsi0N4[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[1,0].set_xlabel(r'$t$', fontsize=12)
axs[1,0].tick_params(right=True, top=True, direction='in')
axs[1,0].set_xticks([0,2,4,6,8])
axs[1,0].set_title(r'$| \psi (0) \rangle_B=|4\rangle^{{\otimes 2}}|0\rangle^{{\otimes 2}}$',loc='left', fontsize=12)
axs[1,0].text(0.93, 0.88, r'\bf (d)', horizontalalignment='center', verticalalignment='center', transform=axs[1,0].transAxes)

for inds in range(4):
    axs[0,1].plot(dataNpairN4v2[inds,0],dataNpairN4v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,1].set_ylim([2.7,4.1])
axs[0,1].set_yticks([3,4])
axs[0,1].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[0,1].tick_params(right=True, top=True, direction='in')
axs[0,1].text(0.93, 0.88, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=axs[0,1].transAxes)

for inds in range(4):
    axs[1,1].plot(dataNpairN4[inds,0],dataNpairN4[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,1].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[1,1].set_xlabel(r'$t$', fontsize=12)
axs[1,1].set_ylim([2.7,4.1])
axs[1,1].set_yticks([3,4])
axs[1,1].set_xticks([0,2,4,6,8])
axs[1,1].tick_params(right=True, top=True, direction='in')
axs[1,1].text(0.93, 0.88, r'\bf (e)', horizontalalignment='center', verticalalignment='center', transform=axs[1,1].transAxes)

for inds in range(4):
    axs[0,2].plot(dataTzN4v2[inds,0],dataTzN4v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,2].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-3)
axs[0,2].set_ylim([-4.2,4.2])
axs[0,2].set_yticks([-4,-2,0,2,4])
axs[0,2].tick_params(right=True, top=True, direction='in')
axs[0,2].text(0.93, 0.88, r'\bf (c)', horizontalalignment='center', verticalalignment='center', transform=axs[0,2].transAxes)

for inds in range(4):
    axs[1,2].plot(dataTzN4[inds,0],dataTzN4[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,2].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-3)
axs[1,2].set_xlabel(r'$t$', fontsize=12)
axs[1,2].set_ylim([-4.2,4.2])
axs[1,2].set_yticks([-4,-2,0,2,4])
axs[1,2].set_xticks([0,2,4,6,8])
axs[1,2].tick_params(right=True, top=True, direction='in')
axs[1,2].text(0.93, 0.88, r'\bf (f)', horizontalalignment='center', verticalalignment='center', transform=axs[1,2].transAxes)

fig.align_ylabels()

with PdfPages('Nq4_initwvfn12_longT_2.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()

# %%
fig = plt.figure(figsize=(9, 3.5))
axs = fig.subplots(2,3, sharex=True)
plt.subplots_adjust(left=0.08, bottom=0.1, right=0.99, top=0.93, wspace=0.2, hspace=0.2)

colortrot =['#674A40','#50A3A4','#FCAF38','#F95335']

dataPsi0N6 = np.empty((4,2,1001))
dataNpairN6 = np.empty((4,2,1001))
dataTzN6 = np.empty((4,2,1001))

dataPsi0N6v2 = np.empty((4,2,1001))
dataNpairN6v2 = np.empty((4,2,1001))
dataTzN6v2 = np.empty((4,2,1001))

dataPsi0N6[0,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np6_set1_longT.dat'))
dataPsi0N6[1,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np6_set2_longT.dat'))
dataPsi0N6[2,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np6_set3_longT.dat'))
dataPsi0N6[3,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np6_set4_longT.dat'))

dataNpairN6[0,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np6_set1_longT.dat'))
dataNpairN6[1,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np6_set2_longT.dat'))
dataNpairN6[2,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np6_set3_longT.dat'))
dataNpairN6[3,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np6_set4_longT.dat'))

dataTzN6[0,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np6_set1_longT.dat'))
dataTzN6[1,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np6_set2_longT.dat'))
dataTzN6[2,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np6_set3_longT.dat'))
dataTzN6[3,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np6_set4_longT.dat'))

dataPsi0N6v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np6_set1_longT.dat'))
dataPsi0N6v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np6_set2_longT.dat'))
dataPsi0N6v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np6_set3_longT.dat'))
dataPsi0N6v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np6_set4_longT.dat'))

dataNpairN6v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np6_set1_longT.dat'))
dataNpairN6v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np6_set2_longT.dat'))
dataNpairN6v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np6_set3_longT.dat'))
dataNpairN6v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np6_set4_longT.dat'))

dataTzN6v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np6_set1_longT.dat'))
dataTzN6v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np6_set2_longT.dat'))
dataTzN6v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np6_set3_longT.dat'))
dataTzN6v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np6_set4_longT.dat'))

for inds in range(4):
    axs[0,0].plot(dataPsi0N6v2[inds,0],dataPsi0N6v2[inds,1],c=colortrot[inds],marker='',ls='-',label=rf'$\rm{{set}}$-${inds+1}$')
axs[0,0].legend(ncol=2,handlelength=1,columnspacing=1, fontsize=10,loc='upper right')
axs[0,0].set_xlim([-0.05,8.05])
axs[0,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[0,0].tick_params(right=True, top=True, direction='in')
axs[0,0].set_title(r'$| \psi (0) \rangle_A=|1\rangle^{{\otimes 6}}$',loc='left', fontsize=12)
axs[0,0].text(0.08, 0.88, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=axs[0,0].transAxes)

for inds in range(4):
    axs[1,0].plot(dataPsi0N6[inds,0],dataPsi0N6[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[1,0].set_xlabel(r'$t$', fontsize=12)
axs[1,0].tick_params(right=True, top=True, direction='in')
axs[1,0].set_xticks([0,2,4,6,8])
axs[1,0].set_title(r'$| \psi (0) \rangle_B=|4\rangle^{{\otimes 3}}|0\rangle^{{\otimes 3}}$',loc='left', fontsize=12)
axs[1,0].text(0.93, 0.88, r'\bf (d)', horizontalalignment='center', verticalalignment='center', transform=axs[1,0].transAxes)

for inds in range(4):
    axs[0,1].plot(dataNpairN6v2[inds,0],dataNpairN6v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,1].set_ylim([4,6.1])
axs[0,1].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[0,1].tick_params(right=True, top=True, direction='in')
axs[0,1].text(0.93, 0.88, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=axs[0,1].transAxes)

for inds in range(4):
    axs[1,1].plot(dataNpairN6[inds,0],dataNpairN6[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,1].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[1,1].set_xlabel(r'$t$', fontsize=12)
axs[1,1].set_ylim([4,6.1])
axs[1,1].set_xticks([0,2,4,6,8])
axs[1,1].tick_params(right=True, top=True, direction='in')
axs[1,1].text(0.93, 0.88, r'\bf (e)', horizontalalignment='center', verticalalignment='center', transform=axs[1,1].transAxes)

for inds in range(4):
    axs[0,2].plot(dataTzN6v2[inds,0],dataTzN6v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,2].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-3)
axs[0,2].set_ylim([-6.2,6.2])
axs[0,2].set_yticks([-6,-3,0,3,6])
axs[0,2].tick_params(right=True, top=True, direction='in')
axs[0,2].text(0.93, 0.88, r'\bf (c)', horizontalalignment='center', verticalalignment='center', transform=axs[0,2].transAxes)

for inds in range(4):
    axs[1,2].plot(dataTzN6[inds,0],dataTzN6[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,2].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-3)
axs[1,2].set_xlabel(r'$t$', fontsize=12)
axs[1,2].set_ylim([-6.2,6.2])
axs[1,2].set_yticks([-6,-3,0,3,6])
axs[1,2].set_xticks([0,2,4,6,8])
axs[1,2].tick_params(right=True, top=True, direction='in')
axs[1,2].text(0.93, 0.88, r'\bf (f)', horizontalalignment='center', verticalalignment='center', transform=axs[1,2].transAxes)

fig.align_ylabels()

with PdfPages('Nq6_initwvfn12_longT_2.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()

# %%
fig = plt.figure(figsize=(9, 3.5))
axs = fig.subplots(2,3, sharex=True)
plt.subplots_adjust(left=0.08, bottom=0.1, right=0.99, top=0.93, wspace=0.2, hspace=0.2)

colortrot =['#674A40','#50A3A4','#FCAF38','#F95335']

dataPsi0N8 = np.empty((4,2,1001))
dataNpairN8 = np.empty((4,2,1001))
dataTzN8 = np.empty((4,2,1001))

dataPsi0N8v2 = np.empty((4,2,1001))
dataNpairN8v2 = np.empty((4,2,1001))
dataTzN8v2 = np.empty((4,2,1001))

dataPsi0N8[0,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np8_set1_longT.dat'))
dataPsi0N8[1,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np8_set2_longT.dat'))
dataPsi0N8[2,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np8_set3_longT.dat'))
dataPsi0N8[3,:,:] = np.transpose(np.genfromtxt(f'exact/psi0_Np8_set4_longT.dat'))

dataNpairN8[0,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np8_set1_longT.dat'))
dataNpairN8[1,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np8_set2_longT.dat'))
dataNpairN8[2,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np8_set3_longT.dat'))
dataNpairN8[3,:,:] = np.transpose(np.genfromtxt(f'exact/npair_Np8_set4_longT.dat'))

dataTzN8[0,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np8_set1_longT.dat'))
dataTzN8[1,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np8_set2_longT.dat'))
dataTzN8[2,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np8_set3_longT.dat'))
dataTzN8[3,:,:] = np.transpose(np.genfromtxt(f'exact/tz_Np8_set4_longT.dat'))

dataPsi0N8v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np8_set1_longT.dat'))
dataPsi0N8v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np8_set2_longT.dat'))
dataPsi0N8v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np8_set3_longT.dat'))
dataPsi0N8v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/psi0_Np8_set4_longT.dat'))

dataNpairN8v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np8_set1_longT.dat'))
dataNpairN8v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np8_set2_longT.dat'))
dataNpairN8v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np8_set3_longT.dat'))
dataNpairN8v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/npair_Np8_set4_longT.dat'))

dataTzN8v2[0,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np8_set1_longT.dat'))
dataTzN8v2[1,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np8_set2_longT.dat'))
dataTzN8v2[2,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np8_set3_longT.dat'))
dataTzN8v2[3,:,:] = np.transpose(np.genfromtxt(f'exact2/tz_Np8_set4_longT.dat'))

for inds in range(4):
    axs[0,0].plot(dataPsi0N8v2[inds,0],dataPsi0N8v2[inds,1],c=colortrot[inds],marker='',ls='-',label=rf'$\rm{{set}}$-${inds+1}$')
axs[0,0].legend(ncol=2,handlelength=1,columnspacing=1, fontsize=10,loc='upper right')
axs[0,0].set_xlim([-0.05,8.05])
axs[0,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[0,0].tick_params(right=True, top=True, direction='in')
axs[0,0].set_title(r'$| \psi (0) \rangle_A=|1\rangle^{{\otimes 8}}$',loc='left', fontsize=12)
axs[0,0].text(0.08, 0.88, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=axs[0,0].transAxes)

for inds in range(4):
    axs[1,0].plot(dataPsi0N8[inds,0],dataPsi0N8[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,0].set_ylabel(r'$|\langle \psi(t)|\psi(0) \rangle|^2$', fontsize=12)
axs[1,0].set_xlabel(r'$t$', fontsize=12)
axs[1,0].tick_params(right=True, top=True, direction='in')
axs[1,0].set_xticks([0,2,4,6,8])
axs[1,0].set_title(r'$| \psi (0) \rangle_B=|4\rangle^{{\otimes 4}}|0\rangle^{{\otimes 4}}$',loc='left', fontsize=12)
axs[1,0].text(0.93, 0.88, r'\bf (d)', horizontalalignment='center', verticalalignment='center', transform=axs[1,0].transAxes)

for inds in range(4):
    axs[0,1].plot(dataNpairN8v2[inds,0],dataNpairN8v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,1].set_ylim([5.5,8.1])
axs[0,1].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[0,1].tick_params(right=True, top=True, direction='in')
axs[0,1].text(0.93, 0.88, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=axs[0,1].transAxes)

for inds in range(4):
    axs[1,1].plot(dataNpairN8[inds,0],dataNpairN8[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,1].set_ylabel(r'$\langle \hat{N}_{\rm{pairs}}\rangle$', fontsize=12)
axs[1,1].set_xlabel(r'$t$', fontsize=12)
axs[1,1].set_ylim([5.5,8.1])
axs[1,1].set_xticks([0,2,4,6,8])
axs[1,1].tick_params(right=True, top=True, direction='in')
axs[1,1].text(0.93, 0.88, r'\bf (e)', horizontalalignment='center', verticalalignment='center', transform=axs[1,1].transAxes)

for inds in range(4):
    axs[0,2].plot(dataTzN8v2[inds,0],dataTzN8v2[inds,1],c=colortrot[inds],marker='',ls='-')
axs[0,2].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-3)
axs[0,2].set_ylim([-8.2,8.2])
axs[0,2].set_yticks([-8,-4,0,4,8])
axs[0,2].tick_params(right=True, top=True, direction='in')
axs[0,2].text(0.93, 0.88, r'\bf (c)', horizontalalignment='center', verticalalignment='center', transform=axs[0,2].transAxes)

for inds in range(4):
    axs[1,2].plot(dataTzN8[inds,0],dataTzN8[inds,1],c=colortrot[inds],marker='',ls='-')
axs[1,2].set_ylabel(r'$\langle \hat{S}_{z} \rangle$', fontsize=12, labelpad=-3)
axs[1,2].set_xlabel(r'$t$', fontsize=12)
axs[1,2].set_ylim([-8.2,8.2])
axs[1,2].set_yticks([-8,-4,0,4,8])
axs[1,2].set_xticks([0,2,4,6,8])
axs[1,2].tick_params(right=True, top=True, direction='in')
axs[1,2].text(0.93, 0.88, r'\bf (f)', horizontalalignment='center', verticalalignment='center', transform=axs[1,2].transAxes)

fig.align_ylabels()

with PdfPages('Nq8_initwvfn12_longT_2.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()

# %%
fig = plt.figure(figsize=(4.5, 1.8))
axs = fig.subplots(2,1, sharex=True)
plt.subplots_adjust(left=0.16, bottom=0.22, right=0.98, top=0.98, wspace=0, hspace=0.04)
colortrot =['#674A40','#50A3A4','#FCAF38','#F95335']

dataA = np.genfromtxt(f'signprob/overlaps_A.dat')
dataB = np.genfromtxt(f'signprob/overlaps_B.dat')

for inds in range(4):
    axs[0].plot(np.flip(dataA[inds]),c=colortrot[inds],marker='o',ms=2,lw=0,label=rf'$\rm{{set}}$-${inds+1}$')
axs[0].legend(ncol=4,handlelength=0.5,columnspacing=0.8, fontsize=10,loc='upper right')
axs[0].set_xlim([-1,40])
axs[0].set_ylim([0.00001,2])
axs[0].set_yscale("log")
axs[0].minorticks_off()
axs[0].tick_params(right=True, top=True, direction='in')
axs[0].set_yticks([1/10**(5),1/10**(3),1/10**(1)])
axs[0].text(0.13, 0.25, r'{\bf(a)} $| \psi (0) \rangle_A$', horizontalalignment='center', verticalalignment='center', transform=axs[0].transAxes)

for inds in range(4):
    axs[1].plot(np.flip(dataB[inds]),c=colortrot[inds],marker='o',ms=2,lw=0,label=rf'$\rm{{set}}$-${inds+1}$')

axs[1].set_yscale("log")
axs[1].set_ylim([0.00001,2])
axs[1].set_xlabel(r'$i$', fontsize=12)
axs[1].minorticks_off()
axs[1].tick_params(right=True, top=True, direction='in')
axs[1].set_yticks([1/10**(5),1/10**(3),1/10**(1)])
axs[1].text(0.13, 0.25, r'{\bf(b)} $| \psi (0) \rangle_B$', horizontalalignment='center', verticalalignment='center', transform=axs[1].transAxes)

fig.text(0.027, 0.6,r'$|\langle \psi^{(i)}_H|\psi(0) \rangle|^2$', fontsize=12, ha='center', va='center', rotation='vertical')
with PdfPages('Nq4_overlaps_2.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()

# %%
npairsN2=4

set1=[1,0.5,0.5]
set2=[1,1.5,0.5]
set3=[1,0.5,1.5]
set4=[1,1.5,1.5]
sets=[set4]

ntrotsteps = [1,2,4,8,16,32]

dataPsi0N2 = np.empty((len(sets),len(ntrotsteps),5**npairsN2))
dataNpairN2 = np.empty((len(sets),len(ntrotsteps),5**npairsN2))
dataTzN2 = np.empty((len(sets),len(ntrotsteps),5**npairsN2))

dataPsi0N2[0,:,:]=np.loadtxt("signprob/psiB_psi0.txt")
dataNpairN2[0,:,:]=np.loadtxt("signprob/psiB_npair.txt")
dataTzN2[0,:,:]=np.loadtxt("signprob/psiB_tz.txt")

dataPsi0N2b = np.empty((len(sets),len(ntrotsteps),5**npairsN2))
dataNpairN2b = np.empty((len(sets),len(ntrotsteps),5**npairsN2))
dataTzN2b = np.empty((len(sets),len(ntrotsteps),5**npairsN2))

dataPsi0N2b[0,:,:]=np.loadtxt("signprob/psiA_psi0.txt")
dataNpairN2b[0,:,:]=np.loadtxt("signprob/psiA_npair.txt")
dataTzN2b[0,:,:]=np.loadtxt("signprob/psiA_tz.txt")

# %%
list0 = [289, 433, 213, 189, 309, 437, 337, 293, 413, 317, 193, 333, 183, 163, \
187, 307, 283, 287, 601, 25, 105, 521, 505, 121, 169, 209, 457, 217, \
409, 417, 205, 509, 109, 221, 117, 229, 149, 529, 45, 477, 49, 145, \
405, 421, 541, 397, 517, 581, 85, 577, 241, 97, 385, 481, 65, 321, \
513, 561, 113, 305, 353, 273, 553, 73, 265, 361, 439, 319, 463, 339, \
443, 343, 469, 219, 419, 467, 459, 313, 119, 519, 399, 471, 95, 455, \
479, 591, 579, 99, 491, 395, 35, 107, 155, 171, 231, 507, 531, 47, \
135, 147, 227, 527, 159, 167, 207, 407, 157]

new_arr_psi0 = [dataPsi0N2[0,0][np.array(list0)-1], \
dataPsi0N2[0,1][np.array(list0)-1], \
dataPsi0N2[0,2][np.array(list0)-1], \
dataPsi0N2[0,3][np.array(list0)-1], \
dataPsi0N2[0,4][np.array(list0)-1], \
dataPsi0N2[0,5][np.array(list0)-1]]

list0b = [95, 395, 99, 399, 283, 183, 187, 287, 49, 149, 45, 385, 145, 85, 97, \
397, 463, 319, 231, 227, 531, 527, 439, 339, 343, 443, 459, 219, 419, \
467, 307, 163, 471, 455, 519, 119, 189, 433, 333, 437, 193, 289, 337, \
293, 157, 317, 413, 213, 309, 469, 169, 457, 305, 113, 321, 513, 209, \
409, 417, 217, 105, 505, 521, 121, 579, 591, 491, 479, 405, 109, 117, \
509, 517, 205, 421, 221, 65, 265, 73, 273, 313, 167, 159, 207, 407, \
155, 107, 171, 507, 35, 147, 47, 135, 229, 241, 529, 477, 481, 541, \
577, 581, 353, 361, 561, 553, 25, 601]

new_arr_psi0b = [dataPsi0N2b[0,0][np.array(list0b)-1], \
dataPsi0N2b[0,1][np.array(list0b)-1], \
dataPsi0N2b[0,2][np.array(list0b)-1], \
dataPsi0N2b[0,3][np.array(list0b)-1], \
dataPsi0N2b[0,4][np.array(list0b)-1], \
dataPsi0N2b[0,5][np.array(list0b)-1]]

# %%
list0 = [157, 407, 167, 207, 159, 227, 527, 47, 147, 135, 35, 107, 155, 171, \
231, 507, 531, 283, 287, 187, 307, 163, 183, 439, 463, 319, 339, 443, \
343, 219, 419, 467, 459, 119, 519, 399, 471, 95, 455, 479, 591, 579, \
99, 491, 395, 469]

new_arr_sz = [dataTzN2[0,0][np.array(list0)-1], \
dataTzN2[0,1][np.array(list0)-1], \
dataTzN2[0,2][np.array(list0)-1], \
dataTzN2[0,3][np.array(list0)-1], \
dataTzN2[0,4][np.array(list0)-1], \
dataTzN2[0,5][np.array(list0)-1]]

list0b = [47, 135, 35, 147, 507, 107, 171, 155, 159, 207, 407, 167, 157, 163, \
307, 527, 531, 227, 231, 287, 187, 183, 283, 95, 395, 99, 399, 463, \
319, 439, 339, 343, 443, 459, 419, 219, 467, 471, 455, 519, 119, 579, \
591, 491, 479, 469]

new_arr_szb = [dataTzN2b[0,0][np.array(list0b)-1], \
dataTzN2b[0,1][np.array(list0b)-1], \
dataTzN2b[0,2][np.array(list0b)-1], \
dataTzN2b[0,3][np.array(list0b)-1], \
dataTzN2b[0,4][np.array(list0b)-1], \
dataTzN2b[0,5][np.array(list0b)-1]]

# %%
exactpsi0 = [0.000375467, 0.000375467, 0.000375467, 0.000375467, 0.000375467, \
0.000375467, 0.000375467, 0.000375467, 0.000375467, 0.000375467, \
0.000375467, 0.000375467, 0.00223631, 0.00223631, 0.00223631, \
0.00223631, 0.00223631, 0.00223631, 0.0026367, 0.0026367, 0.0026367, \
0.0026367, 0.0026367, 0.0026367, 0.00264525, 0.00264525, 0.00264525, \
0.00264525, 0.00264525, 0.00264525, 0.00280336, 0.00280336, \
0.00280336, 0.00280336, 0.00280336, 0.00280336, 0.00280336, \
0.00280336, 0.00280336, 0.00280336, 0.00280336, 0.00280336, \
0.00280336, 0.00280336, 0.00280336, 0.00280336, 0.00280336, \
0.00280336, 0.00280336, 0.00280336, 0.00280336, 0.00280336, \
0.00280336, 0.00280336, 0.00380765, 0.00380765, 0.00380765, \
0.00380765, 0.00380765, 0.00380765, 0.00380765, 0.00380765, \
0.00380765, 0.00380765, 0.00380765, 0.00380765, 0.00466198, \
0.00466198, 0.00466198, 0.00466198, 0.00466198, 0.00466198, \
0.00573445, 0.00610057, 0.00610057, 0.00610057, 0.00610057, \
0.00882477, 0.00926195, 0.00926195, 0.00926195, 0.00926195, \
0.00926195, 0.00926195, 0.00926195, 0.00926195, 0.00926195, \
0.00926195, 0.00926195, 0.00926195, 0.0257218, 0.0257218, 0.0257218, \
0.0257218, 0.0257218, 0.0257218, 0.0257218, 0.0257218, 0.0257218, \
0.0257218, 0.0257218, 0.0257218, 0.0327127, 0.0327127, 0.0327127, \
0.0327127, 0.219823]

exactpsi0b = [0.0000720765, 0.0000720765, 0.0000720765, 0.0000720765, 0.000285194, \
0.000285194, 0.000285194, 0.000285194, 0.000796127, 0.000796127, \
0.000796127, 0.000796127, 0.000796127, 0.000796127, 0.000796127, \
0.000796127, 0.00084905, 0.00084905, 0.000950992, 0.000950992, \
0.000950992, 0.000950992, 0.00118425, 0.00118425, 0.00118425, \
0.00118425, 0.00172404, 0.00172404, 0.00172404, 0.00172404, \
0.00191797, 0.00191797, 0.00214604, 0.00214604, 0.00214604, \
0.00214604, 0.00230237, 0.00230237, 0.00230237, 0.00230237, \
0.00230237, 0.00230237, 0.00230237, 0.00230237, 0.0026367, \
0.00293156, 0.00293156, 0.00293156, 0.00293156, 0.00293672, \
0.00296153, 0.00296153, 0.00332712, 0.00332712, 0.00332712, \
0.00332712, 0.00455275, 0.00455275, 0.00455275, 0.00455275, \
0.00460016, 0.00460016, 0.00460016, 0.00460016, 0.00510741, \
0.00510741, 0.00510741, 0.00510741, 0.00511046, 0.00511046, \
0.00511046, 0.00511046, 0.00511046, 0.00511046, 0.00511046, \
0.00511046, 0.00524016, 0.00524016, 0.00524016, 0.00524016, \
0.00547386, 0.00618877, 0.00618877, 0.00618877, 0.00618877, \
0.00856072, 0.00856072, 0.00856072, 0.00856072, 0.0151667, 0.0151667, \
0.0151667, 0.0151667, 0.0212575, 0.0212575, 0.0212575, 0.0212575, \
0.0212575, 0.0212575, 0.0212575, 0.0212575, 0.0245743, 0.0245743, \
0.0245743, 0.0245743, 0.15137, 0.243946]

# %%
exactSz = [-0.879293, -0.0654254, -0.0654254, -0.0654254, -0.0654254, \
-0.0514436, -0.0514436, -0.0514436, -0.0514436, -0.0514436, \
-0.0514436, -0.0514436, -0.0514436, -0.0514436, -0.0514436, \
-0.0514436, -0.0514436, -0.00447263, -0.00447263, -0.00447263, \
-0.00447263, -0.00447263, -0.00447263, 0.00932396, 0.00932396, \
0.00932396, 0.00932396, 0.00932396, 0.00932396, 0.0122011, 0.0122011, \
0.0122011, 0.0122011, 0.0185239, 0.0185239, 0.0185239, 0.0185239, \
0.0185239, 0.0185239, 0.0185239, 0.0185239, 0.0185239, 0.0185239, \
0.0185239, 0.0185239, 0.0229378]

exactSzb = [-0.0303333, -0.0303333, -0.0303333, -0.0303333, -0.0171214, \
-0.0171214, -0.0171214, -0.0171214, -0.0123775, -0.0123775, \
-0.0123775, -0.0123775, -0.0105468, -0.00383594, -0.00383594, \
-0.00190198, -0.00190198, -0.00190198, -0.00190198, -0.000570388, \
-0.000570388, -0.000570388, -0.000570388, 0.000144153, 0.000144153, \
0.000144153, 0.000144153, 0.0016981, 0.0016981, 0.00236849, \
0.00236849, 0.00236849, 0.00236849, 0.00344809, 0.00344809, \
0.00344809, 0.00344809, 0.00429208, 0.00429208, 0.00429208, \
0.00429208, 0.0102148, 0.0102148, 0.0102148, 0.0102148, 0.0117469]

# %%
import matplotlib.patheffects as pe

fig = plt.figure(layout='constrained', figsize=(10, 6))
axs = fig.subplots(2, 2)

colortrot =['#FFC75F','#FF9671','#FF6F91','#D65DB1','#845EC2','#403095']
ntrotsteps = [1,2,4,8,16,32]

for indt,ntrot in enumerate(ntrotsteps):
    axs[0,0].bar(list(range(len(new_arr_psi0[indt]))),np.flip(np.sort(new_arr_psi0[indt])), color=colortrot[indt])

axs[0,0].plot(np.flip(exactpsi0), marker="_", color="black",linewidth=0,markersize=2.5,markeredgewidth=1.5)
axs[0,0].plot(np.flip(exactpsi0), marker="_", color="white",linewidth=0,markersize=2.5,markeredgewidth=0.6)

axs[0,0].set_xlim(-1,len(new_arr_psi0[0]))
axs[0,0].set_ylim(0.00006,0.3)
axs[0,0].set_yscale("log")
axs[0,0].minorticks_off()
axs[0,0].text(0.96, 0.92, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=axs[0,0].transAxes)
axs[0,0].set_ylabel(r'$|\langle i|\psi(t) \rangle|^2$', fontsize=14)
axs[0,0].tick_params(right=True, top=True, direction='in',which='both')
axs[0,0].set_title(r'$| \psi (0) \rangle_A=|1\rangle^{{\otimes 4}}$', loc='left')

for indt,ntrot in enumerate(ntrotsteps):
    axs[0,1].bar(list(range(len(new_arr_psi0b[indt]))),np.flip(np.sort(new_arr_psi0b[indt])), color=colortrot[indt])

axs[0,1].plot(np.flip(exactpsi0b), marker="_", color="black",linewidth=0,markersize=2.5,markeredgewidth=1.5)
axs[0,1].plot(np.flip(exactpsi0b), marker="_", color="white",linewidth=0,markersize=2.5,markeredgewidth=0.6)

axs[0,1].set_xlim(-1,len(new_arr_psi0b[0]))
axs[0,1].set_ylim(0.00006,0.3)
axs[0,1].set_yscale("log")
axs[0,1].minorticks_off()
axs[0,1].text(0.96, 0.92, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=axs[0,1].transAxes)
axs[0,1].tick_params(right=True, top=True, direction='in',which='both')
axs[0,1].set_title(r'$| \psi (0) \rangle_B=|4\rangle^{{\otimes 2}}\otimes|0\rangle^{{\otimes 2}}$', loc='left')

for indt,ntrot in enumerate(ntrotsteps):
    axs[1,0].bar(list(range(len(new_arr_sz[indt]))),np.flip(np.sort(new_arr_sz[indt])), color=colortrot[indt])

axs[1,0].plot(np.flip(exactSz), marker="_", color="black",linewidth=0,markersize=5,markeredgewidth=1.5)
axs[1,0].plot(np.flip(exactSz), marker="_", color="white",linewidth=0,markersize=5,markeredgewidth=0.6)

axs[1,0].set_xlim(-1,len(new_arr_sz[0]))
axs[1,0].text(0.05, 0.07, r'\bf (c)', horizontalalignment='center', verticalalignment='center', transform=axs[1,0].transAxes)
axs[1,0].set_ylabel(r'$\langle \psi(t) | i \rangle\langle i |\hat{S}_z| \psi(t)\rangle$', fontsize=14)
axs[1,0].set_xlabel(r'$\tilde{| i \rangle}$', fontsize=14)
axs[1,0].tick_params(right=True, top=True, direction='in',which='both')


for indt,ntrot in enumerate(ntrotsteps):
    axs[1,1].bar(list(range(len(new_arr_szb[indt]))),np.flip(np.sort(new_arr_szb[indt])), color=colortrot[indt],label=f'$n_{{\\rm{{Trot}}}}={ntrot}$')

axs[1,1].plot(np.flip(exactSzb), marker="_", color="black",linewidth=0,markersize=5,markeredgewidth=1.5)
axs[1,1].plot(np.flip(exactSzb), marker="_", color="white",linewidth=0,markersize=5,markeredgewidth=0.6)

axs[1,1].plot(np.NaN, np.NaN, color='white', lw=2, path_effects=[pe.Stroke(linewidth=5, foreground='k'), pe.Normal()],label=r'$\rm{{Exact}}$')
axs[1,1].plot(np.NaN, np.NaN, '-', color='none', label=' ')  #Needed for extra space in legend between points and line
handles, labels = axs[1,1].get_legend_handles_labels()
axs[1,1].legend(handles=handles[2:5]+[handles[1]]+handles[5:]+[handles[0]], labels=labels[2:5]+[labels[1]]+labels[5:]+[labels[0]]
              ,ncol=2,handlelength=0.8,handleheight=0.1,columnspacing=1.2,loc='upper right')


axs[1,1].set_xlim(-1,len(new_arr_szb[0]))
axs[1,1].text(0.05, 0.07, r'\bf (d)', horizontalalignment='center', verticalalignment='center', transform=axs[1,1].transAxes)
axs[1,1].set_xlabel(r'$\tilde{| i \rangle}$', fontsize=14)
axs[1,1].tick_params(right=True, top=True, direction='in',which='both')

with PdfPages('Nq4_stn_3.pdf') as pdf:
    pdf.savefig(transparent=True)

plt.show()

# %%
from matplotlib.markers import MarkerStyle

modepairs = np.arange(2,21,1, dtype=np.float64)
qu5dim = 5**(modepairs)
qu2JWdim = 2**(4*modepairs)
qu2StSdim = 2**(3*modepairs)

qu5gates = modepairs*(modepairs-1)*160
qu5gates2 = modepairs*(modepairs-1)*20
qu2JWgates = modepairs*(modepairs-1)*64+modepairs*14
qu2StSgates = modepairs*(modepairs-1)*344+modepairs*10


fig = plt.figure(figsize=(5, 3))
ax1 = fig.subplots(1,2)
plt.subplots_adjust(left=0.13, bottom=0.14, right=0.89, top=0.97, wspace=0, hspace=0)

ax1[0].plot(modepairs,qu5dim, linewidth=0.8, linestyle='-', color='#DDAA33', marker=MarkerStyle("o", fillstyle="right"), markersize=5, mew=1, mfc='#DDAA33', markerfacecoloralt='white')
ax1[0].plot(modepairs,qu2JWdim, linewidth=0.8, linestyle='-', color='#BB5566', marker='s', markersize=5,mew=1.2,mfc='white')
ax1[0].plot(modepairs,qu2StSdim, linewidth=0.8, linestyle='-' , color='#004488' , marker='>', markersize=5,mew=1.2,mfc='white')

ax1[0].set_yscale('log')
ax1[0].tick_params(top=True, which='both',direction='in')
ax1[0].minorticks_off()
ax1[0].set_ylabel(r'${\rm dim}(\hat{H})$', fontsize=16)
ax1[0].set_xlabel(r'$\Omega/2$', fontsize=14)
ax1[0].set_xlim([1, 21])
ax1[0].set_xticks([2,8,14,20])
ax1[0].text(0.1, 0.93, r'\bf (a)', horizontalalignment='center', verticalalignment='center', transform=ax1[0].transAxes)


ax1[1].plot(modepairs,qu5gates, linewidth=0.8, linestyle='-', color='#DDAA33', marker='o', markersize=5,mew=1.2,mfc='white', label=r'q5-$C\hat{X}$')
ax1[1].plot(modepairs,qu5gates2, linewidth=0.8, linestyle='-', color='#DDAA33', marker='o', markersize=5,mew=1.2,mfc='#DDAA33', label=r'q5-$G^{\hat{\mathcal{X}}\hat{\mathcal{X}}}$')
ax1[1].plot(modepairs,qu2JWgates, linewidth=0.8, linestyle='-', color='#BB5566', marker='s', markersize=5,mew=1.2,mfc='white', label='q2paJW')
ax1[1].plot(modepairs,qu2StSgates, linewidth=0.8, linestyle='-', color='#004488' , marker='>', markersize=5,mew=1.2,mfc='white', label='q2StS')

ax1[1].set_yscale('log')
ax1[1].tick_params(top=True, which='both', direction='in')
ax1[1].minorticks_off()
ax1[1].tick_params(which='minor', right=False, left=False)
ax1[1].yaxis.set_label_position("right")
ax1[1].yaxis.tick_right()
ax1[1].set_ylabel(r'$\#\rm{entangling\ gates}$', fontsize=16)
ax1[1].set_xlabel(r'$\Omega/2$', fontsize=14)
ax1[1].set_xlim([1, 21])
ax1[1].set_xticks([2,8,14,20])
ax1[1].text(0.1, 0.93, r'\bf (b)', horizontalalignment='center', verticalalignment='center', transform=ax1[1].transAxes)
ax1[1].legend(fontsize=10)


with PdfPages('dimH_ngates.pdf') as pdf:
    pdf.savefig(transparent=True)
    
plt.show()
